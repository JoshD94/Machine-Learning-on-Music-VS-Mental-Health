# %%
# Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Read data
csv_filename = "mxmh_survey_results.csv"
raw_data = pd.read_csv(csv_filename).dropna()
raw_data.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6  8/27/2022 22:00:29  18.0             YouTube Music            3.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
# 5           Yes             Yes      Yes              Jazz         Yes
# 6           Yes             Yes       No  Video game music         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 2               Yes  ...            Never           Rarely           Rarely
# 3               Yes  ...        Sometimes            Never            Never
# 4                No  ...  Very frequently  Very frequently            Never
# 5               Yes  ...  Very frequently  Very frequently  Very frequently
# 6               Yes  ...           Rarely            Never            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
# 5                        Never     8.0        8.0      7.0  7.0       Improve
# 6                    Sometimes     4.0        8.0      6.0  0.0       Improve
#
#      Permissions
# 2  I understand.
# 3  I understand.
# 4  I understand.
# 5  I understand.
# 6  I understand.
#
# [5 rows x 33 columns]

# %%
# Get only integer values for now
only_integer_data = raw_data.select_dtypes(include='number')

# %%
# Correlation Matrix
corr = only_integer_data.corr()
corr
# Out:
#                     Age  Hours per day       BPM   Anxiety  Depression  \
# Age            1.000000      -0.044917 -0.030435 -0.193781   -0.087390
# Hours per day -0.044917       1.000000  0.043320  0.036945    0.085559
# BPM           -0.030435       0.043320  1.000000 -0.027564    0.041804
# Anxiety       -0.193781       0.036945 -0.027564  1.000000    0.527950
# Depression    -0.087390       0.085559  0.041804  0.527950    1.000000
# Insomnia       0.007083       0.119036  0.054452  0.275013    0.372675
# OCD           -0.140464       0.108197  0.018939  0.339262    0.158990
#
#                Insomnia       OCD
# Age            0.007083 -0.140464
# Hours per day  0.119036  0.108197
# BPM            0.054452  0.018939
# Anxiety        0.275013  0.339262
# Depression     0.372675  0.158990
# Insomnia       1.000000  0.198866
# OCD            0.198866  1.000000

# %%
# Convert string columns into integers
integer_data = raw_data.copy()
integer_data = integer_data.drop("Permissions", axis=1)
integer_data = integer_data.replace(["Yes"], 1.0)
integer_data = integer_data.replace(["No"], 0.0)
integer_data = integer_data.replace(["No effect"], 0.0)
integer_data = integer_data.replace(["Improve"], 1.0)
integer_data = integer_data.replace(["Worsen"], -1.0)

integer_data = integer_data.replace(["Never"], -2.0)
integer_data = integer_data.replace(["Rarely"], -1.0)
integer_data = integer_data.replace(["Sometimes"], 1.0)
integer_data = integer_data.replace(["Very frequently"], 2.0)

print(integer_data.head())
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6  8/27/2022 22:00:29  18.0             YouTube Music            3.0
#
#    While working  Instrumentalist  Composer         Fav genre  Exploratory  \
# 2            0.0              0.0       0.0  Video game music          0.0
# 3            1.0              0.0       1.0              Jazz          1.0
# 4            1.0              0.0       0.0               R&B          1.0
# 5            1.0              1.0       1.0              Jazz          1.0
# 6            1.0              1.0       0.0  Video game music          1.0
#
#    Foreign languages  ...  Frequency [Pop]  Frequency [R&B]  Frequency [Rap]  \
# 2                1.0  ...             -1.0             -2.0             -1.0
# 3                1.0  ...              1.0              1.0             -2.0
# 4                0.0  ...              1.0              2.0              2.0
# 5                1.0  ...              2.0              2.0              2.0
# 6                1.0  ...             -1.0             -1.0             -2.0
#
#    Frequency [Rock]  Frequency [Video game music]  Anxiety  Depression  \
# 2              -1.0                           2.0      7.0         7.0
# 3              -2.0                          -2.0      9.0         7.0
# 4              -2.0                          -1.0      7.0         2.0
# 5               2.0                          -2.0      8.0         8.0
# 6              -2.0                           1.0      4.0         8.0
#
#    Insomnia  OCD  Music effects
# 2      10.0  2.0            0.0
# 3       3.0  3.0            1.0
# 4       5.0  9.0            1.0
# 5       7.0  7.0            1.0
# 6       6.0  0.0            1.0
#
# [5 rows x 32 columns]

# %%
# Correlation Matrix after changing to integers
corr = integer_data.select_dtypes(include='number').corr()
corr
# Out:
#                                    Age  Hours per day  While working  \
# Age                           1.000000      -0.044917      -0.056722
# Hours per day                -0.044917       1.000000       0.284923
# While working                -0.056722       0.284923       1.000000
# Instrumentalist              -0.092986      -0.020598       0.085167
# Composer                     -0.020728       0.151102       0.053883
# Exploratory                  -0.176944       0.127432       0.174944
# Foreign languages            -0.115733       0.083713       0.121532
# BPM                          -0.030435       0.043320       0.020448
# Frequency [Classical]         0.102132      -0.031240       0.079333
# Frequency [Country]           0.128320       0.037744      -0.029889
# Frequency [EDM]              -0.076992       0.126162       0.149832
# Frequency [Folk]              0.134422       0.082749       0.018952
# Frequency [Gospel]            0.120655       0.026249       0.062076
# Frequency [Hip hop]          -0.141047       0.135893       0.047492
# Frequency [Jazz]              0.093591       0.120583       0.092932
# Frequency [K pop]            -0.160901       0.071243       0.133693
# Frequency [Latin]             0.073499       0.065220       0.090480
# Frequency [Lofi]             -0.182507       0.099499       0.157390
# Frequency [Metal]            -0.026569       0.131885       0.045372
# Frequency [Pop]              -0.171548      -0.057754       0.088932
# Frequency [R&B]               0.027029       0.116811       0.127298
# Frequency [Rap]              -0.186776       0.172164       0.097349
# Frequency [Rock]              0.072391       0.063150      -0.003688
# Frequency [Video game music] -0.240778       0.051381       0.131846
# Anxiety                      -0.193781       0.036945       0.032674
# Depression                   -0.087390       0.085559       0.051999
# Insomnia                      0.007083       0.119036       0.038108
# OCD                          -0.140464       0.108197       0.095216
# Music effects                -0.059195       0.041468       0.146556
#
#                               Instrumentalist  Composer  Exploratory  \
# Age                                 -0.092986 -0.020728    -0.176944
# Hours per day                       -0.020598  0.151102     0.127432
# While working                        0.085167  0.053883     0.174944
# Instrumentalist                      1.000000  0.437047     0.051446
# Composer                             0.437047  1.000000     0.086077
# Exploratory                          0.051446  0.086077     1.000000
# Foreign languages                   -0.039580 -0.015818     0.191773
# BPM                                 -0.027960 -0.018593     0.024390
# Frequency [Classical]                0.239273  0.066645     0.051168
# Frequency [Country]                 -0.041065  0.017820     0.030831
# Frequency [EDM]                     -0.080861  0.023129     0.099590
# Frequency [Folk]                    -0.033141  0.060303     0.147540
# Frequency [Gospel]                   0.055172  0.061728     0.043055
# Frequency [Hip hop]                 -0.174283 -0.038311     0.204804
# Frequency [Jazz]                     0.222345  0.207637     0.166443
# Frequency [K pop]                   -0.041796 -0.024329     0.158394
# Frequency [Latin]                    0.087897  0.049081     0.074618
# Frequency [Lofi]                    -0.006474  0.044340     0.242099
# Frequency [Metal]                    0.067484  0.131898     0.140106
# Frequency [Pop]                     -0.070828 -0.042797     0.195271
# Frequency [R&B]                     -0.100819  0.023729     0.163817
# Frequency [Rap]                     -0.133364 -0.015500     0.211767
# Frequency [Rock]                     0.004851  0.068217     0.161715
# Frequency [Video game music]         0.083900  0.018291     0.007979
# Anxiety                              0.044297  0.011673     0.022410
# Depression                          -0.000458  0.080376     0.057013
# Insomnia                             0.056052  0.100885     0.049736
# OCD                                  0.033615  0.025150     0.035631
# Music effects                        0.090223  0.078434     0.144517
#
#                               Foreign languages       BPM  \
# Age                                   -0.115733 -0.030435
# Hours per day                          0.083713  0.043320
# While working                          0.121532  0.020448
# Instrumentalist                       -0.039580 -0.027960
# Composer                              -0.015818 -0.018593
# Exploratory                            0.191773  0.024390
# Foreign languages                      1.000000 -0.045798
# BPM                                   -0.045798  1.000000
# Frequency [Classical]                  0.123424 -0.049237
# Frequency [Country]                   -0.046815 -0.001306
# Frequency [EDM]                        0.167518  0.042632
# Frequency [Folk]                       0.077935 -0.009150
# Frequency [Gospel]                    -0.001669 -0.020019
# Frequency [Hip hop]                    0.154256 -0.024228
# Frequency [Jazz]                       0.125347 -0.010917
# Frequency [K pop]                      0.326650 -0.027561
# Frequency [Latin]                      0.242827 -0.026588
# Frequency [Lofi]                       0.176158 -0.039123
# Frequency [Metal]                      0.064274  0.060658
# Frequency [Pop]                        0.059186  0.006645
# Frequency [R&B]                        0.154017 -0.045253
# Frequency [Rap]                        0.146300  0.057097
# Frequency [Rock]                       0.000495 -0.050872
# Frequency [Video game music]           0.156477  0.035732
# Anxiety                                0.076930 -0.027564
# Depression                             0.084260  0.041804
# Insomnia                               0.044743  0.054452
# OCD                                   -0.040934  0.018939
# Music effects                          0.016577 -0.059445
#
#                               Frequency [Classical]  Frequency [Country]  ...  \
# Age                                        0.102132             0.128320  ...
# Hours per day                             -0.031240             0.037744  ...
# While working                              0.079333            -0.029889  ...
# Instrumentalist                            0.239273            -0.041065  ...
# Composer                                   0.066645             0.017820  ...
# Exploratory                                0.051168             0.030831  ...
# Foreign languages                          0.123424            -0.046815  ...
# BPM                                       -0.049237            -0.001306  ...
# Frequency [Classical]                      1.000000            -0.010673  ...
# Frequency [Country]                       -0.010673             1.000000  ...
# Frequency [EDM]                           -0.093500            -0.016147  ...
# Frequency [Folk]                           0.092897             0.346872  ...
# Frequency [Gospel]                         0.109039             0.219984  ...
# Frequency [Hip hop]                       -0.087035             0.041059  ...
# Frequency [Jazz]                           0.316042             0.047954  ...
# Frequency [K pop]                          0.054407            -0.023032  ...
# Frequency [Latin]                          0.134100             0.103057  ...
# Frequency [Lofi]                           0.094179            -0.025472  ...
# Frequency [Metal]                         -0.016311             0.053406  ...
# Frequency [Pop]                            0.052909             0.048409  ...
# Frequency [R&B]                            0.010074             0.060490  ...
# Frequency [Rap]                           -0.142916             0.053216  ...
# Frequency [Rock]                          -0.063237             0.172953  ...
# Frequency [Video game music]               0.094886            -0.085971  ...
# Anxiety                                   -0.017452            -0.008577  ...
# Depression                                 0.023030            -0.075556  ...
# Insomnia                                   0.092941            -0.056198  ...
# OCD                                        0.004039             0.055988  ...
# Music effects                             -0.040001             0.080429  ...
#
#                               Frequency [Pop]  Frequency [R&B]  \
# Age                                 -0.171548         0.027029
# Hours per day                       -0.057754         0.116811
# While working                        0.088932         0.127298
# Instrumentalist                     -0.070828        -0.100819
# Composer                            -0.042797         0.023729
# Exploratory                          0.195271         0.163817
# Foreign languages                    0.059186         0.154017
# BPM                                  0.006645        -0.045253
# Frequency [Classical]                0.052909         0.010074
# Frequency [Country]                  0.048409         0.060490
# Frequency [EDM]                      0.105074         0.122133
# Frequency [Folk]                     0.033105         0.062737
# Frequency [Gospel]                   0.046017         0.241603
# Frequency [Hip hop]                  0.244468         0.520422
# Frequency [Jazz]                     0.067931         0.297769
# Frequency [K pop]                    0.292213         0.331383
# Frequency [Latin]                    0.161640         0.328422
# Frequency [Lofi]                     0.241413         0.243402
# Frequency [Metal]                   -0.177200        -0.152769
# Frequency [Pop]                      1.000000         0.369189
# Frequency [R&B]                      0.369189         1.000000
# Frequency [Rap]                      0.238001         0.483141
# Frequency [Rock]                     0.078927        -0.009733
# Frequency [Video game music]         0.027021        -0.068687
# Anxiety                              0.084080         0.028597
# Depression                           0.056543         0.065380
# Insomnia                            -0.016625         0.006105
# OCD                                  0.029921         0.040007
# Music effects                        0.090210         0.124386
#
#                               Frequency [Rap]  Frequency [Rock]  \
# Age                                 -0.186776          0.072391
# Hours per day                        0.172164          0.063150
# While working                        0.097349         -0.003688
# Instrumentalist                     -0.133364          0.004851
# Composer                            -0.015500          0.068217
# Exploratory                          0.211767          0.161715
# Foreign languages                    0.146300          0.000495
# BPM                                  0.057097         -0.050872
# Frequency [Classical]               -0.142916         -0.063237
# Frequency [Country]                  0.053216          0.172953
# Frequency [EDM]                      0.185652          0.049591
# Frequency [Folk]                     0.026525          0.318471
# Frequency [Gospel]                   0.102397         -0.062591
# Frequency [Hip hop]                  0.767586         -0.048903
# Frequency [Jazz]                     0.119744          0.133476
# Frequency [K pop]                    0.220278         -0.186015
# Frequency [Latin]                    0.175489         -0.035306
# Frequency [Lofi]                     0.227648         -0.036679
# Frequency [Metal]                    0.018403          0.481316
# Frequency [Pop]                      0.238001          0.078927
# Frequency [R&B]                      0.483141         -0.009733
# Frequency [Rap]                      1.000000          0.024943
# Frequency [Rock]                     0.024943          1.000000
# Frequency [Video game music]        -0.001938          0.115494
# Anxiety                              0.043236          0.059683
# Depression                           0.115526          0.190597
# Insomnia                             0.009549          0.078325
# OCD                                  0.014570         -0.023859
# Music effects                        0.051004          0.007467
#
#                               Frequency [Video game music]   Anxiety  \
# Age                                              -0.240778 -0.193781
# Hours per day                                     0.051381  0.036945
# While working                                     0.131846  0.032674
# Instrumentalist                                   0.083900  0.044297
# Composer                                          0.018291  0.011673
# Exploratory                                       0.007979  0.022410
# Foreign languages                                 0.156477  0.076930
# BPM                                               0.035732 -0.027564
# Frequency [Classical]                             0.094886 -0.017452
# Frequency [Country]                              -0.085971 -0.008577
# Frequency [EDM]                                   0.247060  0.053134
# Frequency [Folk]                                  0.037157  0.068716
# Frequency [Gospel]                                0.006304 -0.054662
# Frequency [Hip hop]                              -0.030252  0.021579
# Frequency [Jazz]                                  0.076356  0.011834
# Frequency [K pop]                                 0.062485  0.052049
# Frequency [Latin]                                -0.020712  0.003893
# Frequency [Lofi]                                  0.276378  0.075583
# Frequency [Metal]                                 0.190197  0.030643
# Frequency [Pop]                                   0.027021  0.084080
# Frequency [R&B]                                  -0.068687  0.028597
# Frequency [Rap]                                  -0.001938  0.043236
# Frequency [Rock]                                  0.115494  0.059683
# Frequency [Video game music]                      1.000000  0.098468
# Anxiety                                           0.098468  1.000000
# Depression                                        0.083125  0.527950
# Insomnia                                          0.111582  0.275013
# OCD                                               0.015289  0.339262
# Music effects                                    -0.010963  0.120924
#
#                               Depression  Insomnia       OCD  Music effects
# Age                            -0.087390  0.007083 -0.140464      -0.059195
# Hours per day                   0.085559  0.119036  0.108197       0.041468
# While working                   0.051999  0.038108  0.095216       0.146556
# Instrumentalist                -0.000458  0.056052  0.033615       0.090223
# Composer                        0.080376  0.100885  0.025150       0.078434
# Exploratory                     0.057013  0.049736  0.035631       0.144517
# Foreign languages               0.084260  0.044743 -0.040934       0.016577
# BPM                             0.041804  0.054452  0.018939      -0.059445
# Frequency [Classical]           0.023030  0.092941  0.004039      -0.040001
# Frequency [Country]            -0.075556 -0.056198  0.055988       0.080429
# Frequency [EDM]                 0.057102  0.085250  0.098321       0.048602
# Frequency [Folk]                0.097440  0.045313  0.021503      -0.007762
# Frequency [Gospel]             -0.017418  0.004412  0.010747       0.088137
# Frequency [Hip hop]             0.101971 -0.001540  0.027648       0.038885
# Frequency [Jazz]                0.066269  0.061422 -0.019054       0.043735
# Frequency [K pop]              -0.032279  0.006258  0.048857       0.084438
# Frequency [Latin]               0.015904  0.047513 -0.011133       0.025920
# Frequency [Lofi]                0.038054  0.085176  0.080784       0.069954
# Frequency [Metal]               0.167390  0.143709 -0.029107      -0.024077
# Frequency [Pop]                 0.056543 -0.016625  0.029921       0.090210
# Frequency [R&B]                 0.065380  0.006105  0.040007       0.124386
# Frequency [Rap]                 0.115526  0.009549  0.014570       0.051004
# Frequency [Rock]                0.190597  0.078325 -0.023859       0.007467
# Frequency [Video game music]    0.083125  0.111582  0.015289      -0.010963
# Anxiety                         0.527950  0.275013  0.339262       0.120924
# Depression                      1.000000  0.372675  0.158990      -0.009313
# Insomnia                        0.372675  1.000000  0.198866      -0.008440
# OCD                             0.158990  0.198866  1.000000       0.052105
# Music effects                  -0.009313 -0.008440  0.052105       1.000000
#
# [29 rows x 29 columns]
